# %%
import csv
import requests
from random import randint
import time
import re
from search_jobs import Scraper
from bs4 import BeautifulSoup
import pandas as pd
from data_el_pipeline import *

# %% [markdown]
# # main test
# https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=data%20engineer&start=75

# %%
def test(location="New York", profession="Data Engineer", start=0, end=1000):
    job_postings = []
    start = start # 1000 is the limit
    while start<end:
        time.sleep(randint(0, 5) * 1)
        print(f"Testing {start}")
        try:
            url = (
                f"https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search/?keywords={profession}"
                + (f"&location={location}" if location else "")
                + f"&start={start}"
            )
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            
            result = Scraper().search_results_parsing(response.text)
            job_postings.extend(result)
            start += 25
        except requests.HTTPError as err:
            print(f"[!!] Something went wrong at {start}! {err}")
            break
    return job_postings

# %%
job_list = test(end=50)
# Out:
# Testing 0
# Testing 25

# %%
df = pd.DataFrame(job_list)

# %%
df = search_result_cleaning(df, "Data Engineer")

# %%
df
# Out:
#                                                       Job URL  \
# Job ID
# 3499519671  https://www.linkedin.com/jobs/view/junior-data...
# 3507120914  https://www.linkedin.com/jobs/view/data-engine...
# 3512575736  https://www.linkedin.com/jobs/view/data-engine...
# 3459050990  https://www.linkedin.com/jobs/view/data-engine...
# 3494387251  https://www.linkedin.com/jobs/view/senior-data...
# 3542349990  https://www.linkedin.com/jobs/view/sr-data-eng...
# 3521669493  https://www.linkedin.com/jobs/view/data-engine...
# 3509793440  https://www.linkedin.com/jobs/view/data-engine...
# 3439231800  https://www.linkedin.com/jobs/view/data-engine...
# 3506555861  https://www.linkedin.com/jobs/view/data-engine...
# 3513216706  https://www.linkedin.com/jobs/view/data-engine...
# 3504020464  https://www.linkedin.com/jobs/view/data-engine...
# 3461310036  https://www.linkedin.com/jobs/view/data-engine...
# 3461085680  https://www.linkedin.com/jobs/view/data-engine...
# ...

# %%
df.dtypes
# Out:
# Job ID                  object
# Job URL                 object
# Job Title               object
# Company Name            object
# Location                object
# Salary                  object
# Publish Date    datetime64[ns]
# dtype: object

# %%
start = 975
while True:
    try:
        url = (
            "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search/?keywords=Data Engineer"
            + "&location=New York"
            + f"&start={start}"
        )
        response = requests.get(url, timeout=10)
        response.raise_for_status()
    except requests.HTTPError as err:
            print(f"[!!] Something went wrong at {start}! {err}")
            break
    start += 100
    time.sleep(1.5)
    break

soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify())
# Out:
# <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3520773516" data-row="976" data-search-id="iYOff1d39KGAjNJMErOqBA==" data-tracking-id="iFDHevHEtzHq7515nGXPqw==">
#   <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/software-engineer-defi-at-cryptorecruit-3520773516?refId=iYOff1d39KGAjNJMErOqBA%3D%3D&amp;trackingId=iFDHevHEtzHq7515nGXPqw%3D%3D&amp;position=1&amp;pageNum=39&amp;trk=public_jobs_jserp-result_search-card">
#    <span class="sr-only">
#     Software Engineer - DeFi
#    </span>
#   </a>
#   <div class="search-entity-media">
# ...

# %%
soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify())
# Out:
# <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3520773516" data-row="976" data-search-id="iYOff1d39KGAjNJMErOqBA==" data-tracking-id="iFDHevHEtzHq7515nGXPqw==">
#   <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/software-engineer-defi-at-cryptorecruit-3520773516?refId=iYOff1d39KGAjNJMErOqBA%3D%3D&amp;trackingId=iFDHevHEtzHq7515nGXPqw%3D%3D&amp;position=1&amp;pageNum=39&amp;trk=public_jobs_jserp-result_search-card">
#    <span class="sr-only">
#     Software Engineer - DeFi
#    </span>
#   </a>
#   <div class="search-entity-media">
# ...

# %%
soup = BeautifulSoup(responses[1], "html.parser")
print(soup.prettify())
# Out:
# <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3532534500" data-row="26" data-search-id="Y0ljGLLTipdYACEOyNXJng==" data-tracking-id="EaZZSCwn0B6wmOpYR9/8tQ==">
#   <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/data-analyst-at-ltk-formerly-rewardstyle-liketoknow-it-3532534500?refId=Y0ljGLLTipdYACEOyNXJng%3D%3D&amp;trackingId=EaZZSCwn0B6wmOpYR9%2F8tQ%3D%3D&amp;position=1&amp;pageNum=1&amp;trk=public_jobs_jserp-result_search-card">
#    <span class="sr-only">
#     Data Analyst
#    </span>
#   </a>
#   <div class="search-entity-media">
# ...

# %%
with open("response_900.html", "w") as f:
    f.write(soup.prettify())

# %%
with open("job_postings.csv", "w") as f:
        fieldnames = job_postings[0].keys()
        writer = csv.DictWriter(f, fieldnames=fieldnames)

        writer.writeheader()
        for row in job_postings:
            writer.writerow(row)

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("jobs.csv")
df.head()
# Out:
#        Job ID                                            Job URL  \
# 0  3522520859  https://www.linkedin.com/jobs/view/data-engine...
# 1  3510880916  https://www.linkedin.com/jobs/view/data-engine...
# 2  3534855771  https://www.linkedin.com/jobs/view/new-grad-da...
# 3  3532471645  https://www.linkedin.com/jobs/view/data-engine...
# 4  3527418431  https://www.linkedin.com/jobs/view/data-engine...
#
#                                            Job Title  \
# 0                                      Data Engineer
# 1                                      Data Engineer
# 2  New Grad Data Engineer - Spring 2023 Graduatio...
# 3                                      Data Engineer
# 4                                      Data Engineer
#
#                                 Company Name        Location Salary  \
# 0                                      Dcode  Washington, DC    NaN
# 1                                   CINQCARE  Washington, DC    NaN
# ...

# %%
df['Job ID'].duplicated().sum()
# Out:
# 0

# %%
df['Salary'].isna().sum()
# Out:
# 956

# %%
df.iloc[2:4,[1,5]]
# Out:
#                                              Job URL Salary
# 2  https://www.linkedin.com/jobs/view/new-grad-da...    NaN
# 3  https://www.linkedin.com/jobs/view/data-engine...    NaN

# %%
for url in df.iloc[2:4,[1,5]]:
    print(url)
# Out:
# Job URL
# Salary

# %%
df.loc[df['Job ID'].duplicated(),:]
# Out:
#         Job ID                                            Job URL  \
# 50  3539504883  https://www.linkedin.com/jobs/view/sr-data-eng...
# 51  3533843012  https://www.linkedin.com/jobs/view/data-engine...
# 52  3523177988  https://www.linkedin.com/jobs/view/data-engine...
# 53  3509627398  https://www.linkedin.com/jobs/view/data-analys...
# 54  3510623662  https://www.linkedin.com/jobs/view/data-analys...
# 55  3499583531  https://www.linkedin.com/jobs/view/data-engine...
# 56  3515644963  https://www.linkedin.com/jobs/view/data-engine...
# 57  3512133738  https://www.linkedin.com/jobs/view/senior-data...
# 58  3467037317  https://www.linkedin.com/jobs/view/data-engine...
# 60  3433852371  https://www.linkedin.com/jobs/view/data-engine...
# 61  3535001354  https://www.linkedin.com/jobs/view/data-analys...
# 66  3518855694  https://www.linkedin.com/jobs/view/senior-data...
# 68  3494706178  https://www.linkedin.com/jobs/view/sr-data-eng...
# ...

# %%
df.loc[df["Job ID"] == 3539504883,:]
# Out:
#         Job ID                                            Job URL  \
# 43  3539504883  https://www.linkedin.com/jobs/view/sr-data-eng...
# 50  3539504883  https://www.linkedin.com/jobs/view/sr-data-eng...
#
#            Job Title  Company Name      Location Salary Publish Date
# 43  Sr Data Engineer  NBCUniversal  New York, NY    NaN   2023-03-23
# 50  Sr Data Engineer  NBCUniversal  New York, NY    NaN   2023-03-23

# %%
(df["Job ID"] == 3512575736).sum()
# Out:
# 4

# %% [markdown]
# # Salary problem

# %%
start = 0
try:
    url = (
        "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search/?keywords=Data Engineer"
        + "&location=New York"
        + f"&start={start}"
    )
    response = requests.get(url, timeout=10)
    response.raise_for_status()
except requests.HTTPError as err:
        print(f"[!!] Something went wrong at {start}! {err}")
            

soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify())
# Out:
# <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-column="1" data-entity-urn="urn:li:jobPosting:3499519671" data-row="1" data-search-id="SnEBkSsZKYPnJt5wwbuqkg==" data-tracking-id="QeW6zrhePvDnoRQzVtd2kQ==">
#   <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/junior-data-engineer-at-open-road-media-3499519671?refId=SnEBkSsZKYPnJt5wwbuqkg%3D%3D&amp;trackingId=QeW6zrhePvDnoRQzVtd2kQ%3D%3D&amp;position=1&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
#    <span class="sr-only">
#     Junior Data Engineer
#    </span>
#   </a>
#   <div class="search-entity-media">
# ...

# %%
cursor = 0
for result in soup.find_all("li"):
    salary_info = result.find("span", {"class": "job-search-card__salary-info"})
    if salary_info:
        print(re.sub(re.compile(r"\s+"), "", salary_info.text))
    else:
        company_name = result.find(
                "h4", {"class": "base-search-card__subtitle"}
            ).text.strip()
        print(f"Number {cursor} went wrong, company name: {company_name}")
    cursor += 1
# Out:
# Number 0 went wrong, company name: Open Road Media
# $243,000.00-$312,000.00
# Number 2 went wrong, company name: BLACKBIRD.AI
# Number 3 went wrong, company name: Networx
# Number 4 went wrong, company name: Blue Onion
# Number 5 went wrong, company name: WireScreen
# $75,000.00-$140,000.00
# Number 7 went wrong, company name: TechTA LLC
# Number 8 went wrong, company name: Accrete AI
# Number 9 went wrong, company name: TechTA LLC
# Number 10 went wrong, company name: Perry Health
# Number 11 went wrong, company name: Casdin Capital, LLC
# Number 12 went wrong, company name: Experfy
# Number 13 went wrong, company name: Experfy
# Number 14 went wrong, company name: Attune
# Number 15 went wrong, company name: Software People Inc.
# Number 16 went wrong, company name: ONE
# $134,000.00-$194,000.00
# Number 18 went wrong, company name: Open Road Media
# Number 19 went wrong, company name: Open Road Integrated Media Inc.
# Number 20 went wrong, company name: LTIMindtree
# ...

# %%
url = "https://www.linkedin.com/jobs/view/junior-data-engineer-at-open-road-media-3499519671?refId=2DamthNyBckYaocLciHtoQ%3D%3D&amp;trackingId=0iKQT2hyehj8EiPzl5KuIg%3D%3D&amp;position=2&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card"
dest = "Linkedin Source/Open Road Medi.html"
Scraper().save_source_code(url, dest)
# Out:
# Source code saved to Linkedin Source/Open Road Medi.html

# %% [markdown]
# # Data ingest

# %%
from sqlalchemy import create_engine, MetaData
from sqlalchemy import text
db = "jobs_database"
table_name = "job_search_results"
postgres_url = f'postgresql+psycopg2://root:root@localhost:5432/jobs_database'
engine = create_engine(postgres_url)

# %%
metadata = MetaData()
metadata.reflect(bind=engine)
metadata.drop_all(bind=engine, tables=[metadata.tables['job_search_results']])

# %%
from sqlalchemy import inspect
inspector = inspect(engine)
inspector.has_table('table_name')

# %%
target = pd.read_sql(text('SELECT "Job ID" FROM job_search_results'), engine.connect())
target.head()
# Out:
#        Job ID
# 0  3499519671
# 1  3507120914
# 2  3512575736
# 3  3459050990
# 4  3494387251

# %%
target.dtypes
# Out:
# Job ID    int64
# dtype: object

# %%
target.drop_duplicates(subset=['Job ID'], inplace=True)

# %%
target.duplicated().sum()
# Out:
# 0

# %%
target.shape
# Out:
# (46, 1)

# %%
tmp = df.reset_index().join(target, on="Job ID", how="left", rsuffix="_right")
tmp.head()
# Out:
#        Job ID                                            Job URL  \
# 0  3499519671  https://www.linkedin.com/jobs/view/junior-data...
# 1  3507120914  https://www.linkedin.com/jobs/view/data-engine...
# 2  3512575736  https://www.linkedin.com/jobs/view/data-engine...
# 3  3459050990  https://www.linkedin.com/jobs/view/data-engine...
# 4  3494387251  https://www.linkedin.com/jobs/view/senior-data...
#
#                                Job Title      Company Name      Location  \
# 0                   Junior Data Engineer   Open Road Media  New York, NY
# 1                          Data Engineer  American Express  New York, NY
# 2  Data Engineer, Analytics (Generalist)         Instagram  New York, NY
# 3                          Data Engineer             Adobe  New York, NY
# 4                   Senior Data Engineer    Morgan Stanley  New York, NY
#
#                     Salary Publish Date    Search Term  Job ID_right
# ...

# %%
tmp["Job ID_right"].isna()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45    True
# 46    True
# 47    True
# 48    True
# 49    True
# Name: Job ID_right, dtype: bool

# %%
delta_df = df.reset_index().loc[tmp["Job ID_right"].isna(),:]

# %%
delta_df
# Out:
#         Job ID                                            Job URL  \
# 0   3499519671  https://www.linkedin.com/jobs/view/junior-data...
# 1   3507120914  https://www.linkedin.com/jobs/view/data-engine...
# 2   3512575736  https://www.linkedin.com/jobs/view/data-engine...
# 3   3459050990  https://www.linkedin.com/jobs/view/data-engine...
# 4   3494387251  https://www.linkedin.com/jobs/view/senior-data...
# 5   3542349990  https://www.linkedin.com/jobs/view/sr-data-eng...
# 6   3521669493  https://www.linkedin.com/jobs/view/data-engine...
# 7   3509793440  https://www.linkedin.com/jobs/view/data-engine...
# 8   3439231800  https://www.linkedin.com/jobs/view/data-engine...
# 9   3506555861  https://www.linkedin.com/jobs/view/data-engine...
# 10  3513216706  https://www.linkedin.com/jobs/view/data-engine...
# 11  3504020464  https://www.linkedin.com/jobs/view/data-engine...
# 12  3461310036  https://www.linkedin.com/jobs/view/data-engine...
# ...

# %%
with engine.connect() as conn:
    result = conn.execute(text(f"SELECT * FROM {table_name} LIMIT 5;")).fetchall()
    for row in result:
        print(row)
# Out:
# (None, 3522520859, 'https://www.linkedin.com/jobs/view/data-engineer-at-dcode-3522520859?refId=gqyEvMzvXdpbXD4UL7u%2FKg%3D%3D&trackingId=eOd%2Ffmyr%2BvZLd3%2BhAFsVuQ%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card', 'Data Engineer', 'Dcode', 'Washington, DC', None, '2023-02-14')
# (None, 3510880916, 'https://www.linkedin.com/jobs/view/data-engineer-at-cinqcare-3510880916?refId=gqyEvMzvXdpbXD4UL7u%2FKg%3D%3D&trackingId=AQXxJ8gDaRZqFdpiOqCfCQ%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card', 'Data Engineer', 'CINQCARE', 'Washington, DC', None, '2023-03-03')
# (None, 3534855771, 'https://www.linkedin.com/jobs/view/new-grad-data-engineer-spring-2023-graduation-date-at-blend360-3534855771?refId=gqyEvMzvXdpbXD4UL7u%2FKg%3D%3D&trackingId=fCxCXwMNQTfMyok5y3Hdvg%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card', 'New Grad Data Engineer - Spring 2023 Graduation Date', 'Blend360', 'Columbia, MD', None, '2023-03-22')
# ...

# %% [markdown]
# # JD

# %%
postgres_url = "postgresql+psycopg2://root:root@localhost:5432/jobs_database"
engine = create_engine(postgres_url)
job_id = pd.read_sql(text('SELECT "Job ID", "Job URL"  FROM job_search_results'), engine.connect())
job_id.head()
# Out:
#        Job ID                                            Job URL
# 0  3499519671  https://www.linkedin.com/jobs/view/junior-data...
# 1  3507120914  https://www.linkedin.com/jobs/view/data-engine...
# 2  3512575736  https://www.linkedin.com/jobs/view/data-engine...
# 3  3459050990  https://www.linkedin.com/jobs/view/data-engine...
# 4  3494387251  https://www.linkedin.com/jobs/view/senior-data...

# %%
jobs_sample = job_id.sample(10)
for index, job in jobs_sample.iterrows():
    print(job["Job ID"], job["Job URL"])
# Out:
# 3534440284 https://www.linkedin.com/jobs/view/data-analyst-at-eliassen-group-3534440284?refId=l6cTWi4rr%2FWaie9UyrRsXA%3D%3D&trackingId=nyNXCDcfR7iINrPZfXNH%2BQ%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card
# 3503547706 https://www.linkedin.com/jobs/view/business-intelligence-analyst-at-aptive-environmental-3503547706?refId=DN812LVhPolERZMO8Jf1vg%3D%3D&trackingId=NIkDGCVCnIZPtrXUE6iBdQ%3D%3D&position=23&pageNum=0&trk=public_jobs_jserp-result_search-card
# 3520097906 https://www.linkedin.com/jobs/view/senior-data-engineer-remote-within-usa-at-hewlett-packard-enterprise-3520097906?refId=jq0vFBEre44piAjAIvG9CQ%3D%3D&trackingId=tHVe0U%2F%2BefYAJWzo7qtWcA%3D%3D&position=7&pageNum=1&trk=public_jobs_jserp-result_search-card
# 3535305644 https://www.linkedin.com/jobs/view/system-engineer-at-omni-strategic-technologies-3535305644?refId=pL23LY8OnrJDKlRbG999fA%3D%3D&trackingId=Pz6jK8fAUpTzPfUkt%2BpJVA%3D%3D&position=13&pageNum=1&trk=public_jobs_jserp-result_search-card
# ...

# %%
results = []
for index, job in jobs_sample.iterrows():
    print(job["Job ID"], job["Job URL"])
    try:
        response = requests.get(job["Job URL"], timeout=10)
        response.raise_for_status()
    except requests.HTTPError as err:
            print(f"[!!] Something went wrong! {err}")
    result = Scraper().jd_parsing(html = response.text)
    results.append(dict(job, **result))
# Out:
# 3534440284 https://www.linkedin.com/jobs/view/data-analyst-at-eliassen-group-3534440284?refId=l6cTWi4rr%2FWaie9UyrRsXA%3D%3D&trackingId=nyNXCDcfR7iINrPZfXNH%2BQ%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card
# 3503547706 https://www.linkedin.com/jobs/view/business-intelligence-analyst-at-aptive-environmental-3503547706?refId=DN812LVhPolERZMO8Jf1vg%3D%3D&trackingId=NIkDGCVCnIZPtrXUE6iBdQ%3D%3D&position=23&pageNum=0&trk=public_jobs_jserp-result_search-card
# 3520097906 https://www.linkedin.com/jobs/view/senior-data-engineer-remote-within-usa-at-hewlett-packard-enterprise-3520097906?refId=jq0vFBEre44piAjAIvG9CQ%3D%3D&trackingId=tHVe0U%2F%2BefYAJWzo7qtWcA%3D%3D&position=7&pageNum=1&trk=public_jobs_jserp-result_search-card
# 3535305644 https://www.linkedin.com/jobs/view/system-engineer-at-omni-strategic-technologies-3535305644?refId=pL23LY8OnrJDKlRbG999fA%3D%3D&trackingId=Pz6jK8fAUpTzPfUkt%2BpJVA%3D%3D&position=13&pageNum=1&trk=public_jobs_jserp-result_search-card
# ...

# %%
results
# Out:
# [{'Job ID': 3543556066,
#   'Job URL': 'https://www.linkedin.com/jobs/view/etl-test-engineer-at-diverse-lynx-3543556066?refId=JOBXXmr%2FtEdHWOp5AR19Dg%3D%3D&trackingId=ZNY5vDH71zuBdmsEW%2Bfi0Q%3D%3D&position=23&pageNum=0&trk=public_jobs_jserp-result_search-card',
#   'seniority level': 'Entry level',
#   'employment type': 'Contract',
#   'job function': 'Engineering and Information Technology',
#   'industries': 'Software Development',
# ...

# %%
df_jd = pd.DataFrame(results)
df_jd.head()
# Out:
#        Job ID                                            Job URL  \
# 0  3534440284  https://www.linkedin.com/jobs/view/data-analys...
# 1  3503547706  https://www.linkedin.com/jobs/view/business-in...
# 2  3520097906  https://www.linkedin.com/jobs/view/senior-data...
# 3  3535305644  https://www.linkedin.com/jobs/view/system-engi...
# 4  3483911438  https://www.linkedin.com/jobs/view/data-engine...
#
#     seniority level employment type  \
# 0  Mid-Senior level        Contract
# 1  Mid-Senior level       Full-time
# 2    Not Applicable       Full-time
# 3       Entry level       Full-time
# 4       Entry level       Full-time
#
#                                     job function  \
# 0  Project Management and Information Technology
# 1  Research, Analyst, and Information Technology
# 2                         Information Technology
# 3                         Information Technology
# 4                         Information Technology
#
#                       industries  \
# ...

# %%
df_jd.set_index("Job ID", inplace=True)

# %%
load_data(
        user="root",
        password="root",
        host="localhost",
        port="5432",
        db="jobs_database",
        table_name="job_description",
        df=df_jd,
    )
# Out:
# Table does not exist, creating table job_description

# %%
jdjd = pd.read_sql(text('SELECT *  FROM job_description'), engine.connect())
jdjd.head()
# Out:
#        Job ID                                            Job URL  \
# 0  3534440284  https://www.linkedin.com/jobs/view/data-analys...
# 1  3503547706  https://www.linkedin.com/jobs/view/business-in...
# 2  3520097906  https://www.linkedin.com/jobs/view/senior-data...
# 3  3535305644  https://www.linkedin.com/jobs/view/system-engi...
# 4  3483911438  https://www.linkedin.com/jobs/view/data-engine...
#
#     seniority level employment type  \
# 0  Mid-Senior level        Contract
# 1  Mid-Senior level       Full-time
# 2    Not Applicable       Full-time
# 3       Entry level       Full-time
# 4       Entry level       Full-time
#
#                                     job function  \
# 0  Project Management and Information Technology
# 1  Research, Analyst, and Information Technology
# 2                         Information Technology
# 3                         Information Technology
# 4                         Information Technology
#
#                       industries  \
# ...
